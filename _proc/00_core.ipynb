# %% [raw]
# ---
# description: Test of nbdev
# output-file: core.html
# title: nbio
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(foo)
# Out:
# ---
#
# ### foo
#
# >      foo ()
